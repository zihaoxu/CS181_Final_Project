# %%
import pandas as pd
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt
import itertools

from collections import defaultdict
pd.set_option('max_columns', 100)

# %%
import nltk
import random
from nltk.classify.scikitlearn import SklearnClassifier
import pickle
from sklearn.naive_bayes import MultinomialNB, BernoulliNB
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.svm import SVC, LinearSVC, NuSVC
from nltk.classify import ClassifierI
from statistics import mode
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer, WordNetLemmatizer
from nltk.tokenize import sent_tokenize, word_tokenize
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import confusion_matrix, roc_auc_score
from sklearn.feature_extraction.text import CountVectorizer

# %%
parent_dir = '../Data Sets/'
path_dic = {'B': 'business_s.csv', 'R':'review_text.csv', 'U':'user.csv', 'I':'review_info.csv'}

def read_files():
    d = defaultdict(list)
    for key in path_dic:
        d[key] = pd.read_csv(parent_dir + path_dic[key]).drop('Unnamed: 0', 1)
    return d
def show():
    sns.despine()
    plt.show()
    
def clean_format(w):
    w = w.lower().replace('.', '').replace(',', '').replace('!', '')
    return w
d = read_files()

# %% [markdown]
# # Modify colnames and apply filters

# %%
print(d['B']['review_count'].describe())
print(d['U']['review_count'].describe())
# Out:
# count    135612.000000
# mean         32.286368
# std         102.457144
# min           3.000000
# 25%           5.000000
# 50%           9.000000
# 75%          25.000000
# max        6979.000000
# Name: review_count, dtype: float64
# count    1.183362e+06
# mean     2.372686e+01
# std      8.050645e+01
# min      0.000000e+00
# 25%      2.000000e+00
# 50%      5.000000e+00
# 75%      1.600000e+01
# max      1.165600e+04
# Name: review_count, dtype: float64

# %%
min_review_per_valid_buz = 5
min_review_per_valid_user = 2

d['B'] = d['B'][d['B']['review_count'] >= min_review_per_valid_buz]
d['U'] = d['U'][d['U']['review_count'] >= min_review_per_valid_user]

print(d['B'].shape)
print(d['U'].shape)
# Out:
# (102497, 17)
# (968039, 22)

# %%
print("buz cols: ")
print(list(d['B']))
print()
print("review_text cols: ")
print(list(d['R']))
print()
print("review_info cols: ")
print(list(d['I']))
print()
print("user cols: ")
print(list(d['U']))
# Out:
# buz cols:
# ['address', 'attributes', 'business_id', 'categories', 'city', 'hours', 'is_open', 'latitude', 'longitude', 'name', 'neighborhood', 'postal_code', 'review_count', 'stars', 'state', 'price', 'credit_card']
#
# review_text cols:
# ['text_stem', 'review_id']
#
# review_info cols:
# ['business_id', 'review_cool', 'date', 'review_funny', 'review_id', 'review_stars', 'review_useful', 'user_id', 'polarity', 'subjectivity']
#
# user cols:
# ['average_stars', 'compliment_cool', 'compliment_cute', 'compliment_funny', 'compliment_hot', 'compliment_list', 'compliment_more', 'compliment_note', 'compliment_photos', 'compliment_plain', 'compliment_profile', 'compliment_writer', 'cool', 'elite', 'fans', 'friends', 'funny', 'name', 'review_count', 'useful', 'user_id', 'yelping_since']

# %%
d['R'] = d['R'].merge(d['I'], on = 'review_id', how = 'inner')

# %%
# renaming the columns
d['B'] = d['B'].rename(columns = {'name':'buz_name', 'review_count':'buz_review_count', 'stars':'buz_stars'})
# d['R'] = d['R'].rename(columns = {'cool':'review_cool', 'funny':'review_funny', 'stars':'review_stars', 'useful':'review_useful', \
#                 'text':'review_text'})
d['U'] = d['U'].rename(columns = {'cool':'user_cool', 'funny':'user_funny','useful':'user_useful', 'name':'user_name', \
                                  'review_count':'user_review_count'})

# %%
cols = list(d['B']) + list(d['R']) + list(d['U'])
print("Remaining duplicated cols:", [s for s in cols if cols.count(s) > 1])
# Out:
# Remaining duplicated cols: ['business_id', 'business_id', 'user_id', 'user_id']

# %% [markdown]
# # Calculating polarity and subjectivity using TextBlob

# %%
print(d['R'].shape)
d['R'].head()
# Out:
# (4736897, 11)
#                                            text_stem               review_id  \
# 0  My girlfriend and I stay here for 3 night and ...  VfBHSwC5Vz_pbFluy07i9Q
# 1  If you need an inexpens place to stay for a ni...  3zRpneRKDsOPq92tq7ybAA
# 2  mittlerweil gibt es in edinburgh zwei ableg de...  ne5WhI1jUFOcRn-b-gAzHA
# 3  locat is everyth and thi hotel ha it ! the rec...  llmdwOgDReucVoWEry61Lw
# 4  gute lage im stadtzentrum . shoppingmeil und s...  DuffS87NaSMDmIfluvT83g
#
#               business_id  review_cool        date  review_funny  \
# 0  uYHaNptLzDLoV_JZ_MuzUA          0.0  2016-07-12           0.0
# 1  uYHaNptLzDLoV_JZ_MuzUA          0.0  2016-10-02           0.0
# 2  uYHaNptLzDLoV_JZ_MuzUA          0.0  2015-09-17           0.0
# 3  uYHaNptLzDLoV_JZ_MuzUA          0.0  2016-08-21           0.0
# 4  uYHaNptLzDLoV_JZ_MuzUA          0.0  2013-11-20           0.0
#
#    review_stars  review_useful                 user_id  polarity  subjectivity
# 0           5.0            0.0  cjpdDjZyprfyDG3RlkVG3w  0.311454      0.671768
# 1           3.0            0.0  bjTcT8Ty4cJZhEOEo01FGA  0.133042      0.579203
# 2           3.0            0.0  AXgRULmWcME7J6Ix3I--ww  0.166667      0.833333
# 3           4.0            0.0  oU2SSOmsp_A8JYI7Z2JJ5w  0.204262      0.442840
# 4           5.0            0.0  0xtbPEna2Kei11vsU-U2Mw  0.450000      0.650000

# %%
# from textblob import TextBlob
# d['R']['polarity'] = d['R']['review_text'].apply(lambda s: TextBlob(s).sentiment.polarity)
# d['R']['subjectivity'] = d['R']['review_text'].apply(lambda s: TextBlob(s).sentiment.subjectivity)
# d['R'].head(3)
# Out:
# /Users/zihaoxu/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/zihaoxu/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#               business_id review_cool        date  review_funny  \
# 0  uYHaNptLzDLoV_JZ_MuzUA           0  2016-07-12           0.0
# 1  uYHaNptLzDLoV_JZ_MuzUA           0  2016-10-02           0.0
# 2  uYHaNptLzDLoV_JZ_MuzUA           0  2015-09-17           0.0
#
#                 review_id  review_stars  \
# 0  VfBHSwC5Vz_pbFluy07i9Q           5.0
# 1  3zRpneRKDsOPq92tq7ybAA           3.0
# 2  ne5WhI1jUFOcRn-b-gAzHA           3.0
#
#                                          review_text  review_useful  \
# 0  My girlfriend and I stayed here for 3 nights a...            0.0
# 1  If you need an inexpensive place to stay for a...            0.0
# 2  Mittlerweile gibt es in Edinburgh zwei Ableger...            0.0
#
#                   user_id  polarity  subjectivity
# 0  cjpdDjZyprfyDG3RlkVG3w  0.311454      0.671768
# 1  bjTcT8Ty4cJZhEOEo01FGA  0.133042      0.579203
# 2  AXgRULmWcME7J6Ix3I--ww  0.166667      0.833333

# %%
# save
# d['R'].to_csv(parent_dir + 'review_tagged.csv')

# %%
print(d['R'].shape)
print(list(d['R']))
# Out:
# (4736897, 11)
# ['text_stem', 'review_id', 'business_id', 'review_cool', 'date', 'review_funny', 'review_stars', 'review_useful', 'user_id', 'polarity', 'subjectivity']

# %%
# # Stem all the words in reviews
# length = len(d['R']['review_text'])

# ps = PorterStemmer()
# d['R']['text_stem'] = [' '.join([ps.stem(w) for w in word_tokenize(d['R']['review_text'][i])]) for i in range(length)]

# lemmatizer = WordNetLemmatizer()
# d['R']['text_lemma'] = [' '.join([lemmatizer.lemmatize(w) for w in word_tokenize(d['R']['review_text'][i])]) for i in range(length)]

# %%
# save
# d['R'].to_csv(parent_dir + 'review_tagged2.csv')

# %%
d['R'].loc[0,'text_stem']
# Out:
# 'My girlfriend and I stay here for 3 night and love it . the locat of thi hotel and veri decent price make thi an amaz deal . when you walk out the front door scott monument and princ street are right in front of you , edinburgh castl and the royal mile is a 2 minut walk via a close right around the corner , and there are so mani hidden gem nearbi includ calton hill and the newli open arch that made thi locat incred . the hotel itself wa also veri nice with a reason price bar , veri consider staff , and small but comfort room with excel bathroom and shower . onli two minor complaint are no telephon in room for room servic ( not a huge deal for us ) and no AC in the room , but they have huge window which can be fulli open . the staff were incred though , let us borrow umbrella for the rain , give us map and direct , and also when we had lost our onli UK adapt for charg our phone gave us a veri fanci one for free . I would highli recommend thi hotel to friend , and when I return to edinburgh ( which I most definit will ) I will be stay here without ani hesit .'

# %%
# d['U'] = d['U'].drop('Unnamed: 0', 1)
# d['B'] = d['B'].drop('Unnamed: 0', 1)

# %%
print(list(d['U']))
# Out:
# ['average_stars', 'compliment_cool', 'compliment_cute', 'compliment_funny', 'compliment_hot', 'compliment_list', 'compliment_more', 'compliment_note', 'compliment_photos', 'compliment_plain', 'compliment_profile', 'compliment_writer', 'user_cool', 'elite', 'fans', 'friends', 'user_funny', 'user_name', 'user_review_count', 'user_useful', 'user_id', 'yelping_since']

# %%
d['RU'] = d['U'][['user_id']].merge(d['R'], on = 'user_id', how = 'left')
grouped = d['RU'].groupby('user_id').agg(['count', 'mean', 'std'])
res = pd.DataFrame(grouped.to_records())
print(list(res))
res = res[["user_id", "('review_cool', 'count')", "('review_cool', 'mean')", "('review_funny', 'mean')",\
           "('review_useful', 'mean')", "('review_stars', 'mean')", "('review_stars', 'std')",\
           "('polarity', 'mean')", "('polarity', 'std')", "('subjectivity', 'mean')", "('subjectivity', 'std')"]]

res = res.rename(columns = {"('review_cool', 'count')":"user_review_count", "('review_cool', 'mean')":"user_cool_mean", \
                      "('review_funny', 'mean')":"user_funny_mean","('review_useful', 'mean')":"user_useful_mean", \
                      "('review_stars', 'mean')":"user_star_mean", "('review_stars', 'std')":"user_star_std", \
                      "('polarity', 'mean')":"user_polarity_mean", "('polarity', 'std')":"user_polarity_std", \
                      "('subjectivity', 'mean')":"user_subjectivity_mean", "('subjectivity', 'std')":"user_subjectivity_std"})
res = res.fillna(0)
res.head()
# Out:
# ['user_id', "('review_cool', 'count')", "('review_cool', 'mean')", "('review_cool', 'std')", "('review_funny', 'count')", "('review_funny', 'mean')", "('review_funny', 'std')", "('review_stars', 'count')", "('review_stars', 'mean')", "('review_stars', 'std')", "('review_useful', 'count')", "('review_useful', 'mean')", "('review_useful', 'std')", "('polarity', 'count')", "('polarity', 'mean')", "('polarity', 'std')", "('subjectivity', 'count')", "('subjectivity', 'mean')", "('subjectivity', 'std')"]
#                   user_id  user_review_count  user_cool_mean  user_funny_mean  \
# 0  ---1lKK3aKOuomHnwAkAow                117        0.735043         0.623932
# 1  ---94vtJ_5o_nikEs6hUjg                  1        0.000000         0.000000
# 2  ---PLwSf5gKdIoVnyRHgBA                  2        0.000000         0.000000
# 3  ---cu1hq55BP9DWVXXKHZg                  3        0.000000         0.000000
# 4  ---fhiwiwBYrvqhpXgcWDQ                  1        1.000000         1.000000
#
#    user_useful_mean  user_star_mean  user_star_std  user_polarity_mean  \
# 0          1.572650        4.068376       1.356507            0.212750
# 1          0.000000        5.000000       0.000000            0.566667
# 2          0.000000        4.000000       1.414214            0.239726
# 3          0.333333        2.000000       1.732051            0.066577
# 4          2.000000        1.000000       0.000000           -0.078737
#
#    user_polarity_std  user_subjectivity_mean  user_subjectivity_std
# 0           0.186009                0.548334               0.174480
# 1           0.000000                0.866667               0.000000
# 2           0.315050                0.614042               0.107421
# 3           0.196531                0.613889               0.190090
# 4           0.000000                0.447163               0.000000

# %%
d['U'] = d['U'].rename(columns = {'user_review_count':'user_review_count_original'})
print(list(d['U']))
# Out:
# ['average_stars', 'compliment_cool', 'compliment_cute', 'compliment_funny', 'compliment_hot', 'compliment_list', 'compliment_more', 'compliment_note', 'compliment_photos', 'compliment_plain', 'compliment_profile', 'compliment_writer', 'user_cool', 'elite', 'fans', 'friends', 'user_funny', 'user_name', 'user_review_count_original', 'user_useful', 'user_id', 'yelping_since']

# %%
d['U'] = d['U'].drop(['compliment_cool', 'compliment_cute', 'compliment_funny', 'compliment_hot', \
                      'compliment_list', 'compliment_more', 'compliment_note', 'compliment_photos', \
                      'compliment_plain', 'compliment_profile', 'compliment_writer', 'user_funny', \
                      'user_review_count_original', 'user_useful', 'user_cool'], axis = 1)
d['U'] = d['U'].merge(res, on = 'user_id', how = 'left')
d['U'].head(10)
# Out:
#    average_stars                                              elite  fans  \
# 0           3.80   [2014, 2016, 2013, 2011, 2012, 2015, 2010, 2017]   209
# 1           3.94  [2014, 2017, 2011, 2012, 2015, 2009, 2013, 200...   835
# 2           4.72                                                 []    17
# 3           3.76                                       [2016, 2017]    11
# 4           4.23                                       [2017, 2016]    49
# 5           5.00                                                 []     1
# 6           4.40                                       [2017, 2016]    17
# 7           4.06                                       [2016, 2015]     5
# 8           3.63                                                 []     3
# 9           4.19                                                 []     5
#
#                                              friends  user_name  \
# 0  ['M19NwFwAXKRZzt8koF11hQ', 'QRcMZ8pJJBBZaKubHO...        Cin
# 1  ['eoSSJzdprj3jxXyi94vDXg', 'QF0urZa-0bxga17ZeY...     Andrea
# 2  ['Oa84FFGBw1axX8O6uDkmqg', 'SRcWERSl4rhm-Bz9zN...       Gabe
# 3  ['96DJovjKAtExnyBZRfniPQ', 'Djczq-bRn761U4FW77...       Leah
# 4  ['iN0A6QIrEFYoSGHFaknh8Q', 'B2HDoWNIzLlon0IhS1...       Juan
# 5  ['HanGVaZP_0IwhQdc0F5paQ', '_v1_G2Fs56K8JTAzzI...  Charmaine
# 6  ['ZWD8UH1T7QXQr0Eq-mcWYg', 'ObSXluQeEYiOP9l9mu...   Victoria
# 7  ['Puvuej6lzJ1JOEmtjG7V_Q', 'fq7CL1myWPYeH0d4bK...      Erica
# 8  ['b8NTnxrhHCs6IPAKrzYL9w', 'vaNvEgtznFwSPDNkbM...    Whitney
# 9  ['lM_HnyWHrpBsrgts3VnkxA', 'ynYGa-R1ZJf-tJOVlQ...       Paul
#
#                   user_id yelping_since  user_review_count  user_cool_mean  \
# 0  lsSiIjAKVl-QRxKjRErBeg    2010-07-13                 14       19.714286
# 1  om5ZiponkpRqUNa3pVPiRg    2006-01-18                 72        4.736111
# 2  -lGwMGHMC_XihFJNKCJNRg    2014-10-31                 20        0.350000
# 3  D-ydMTPGWXTVm4_jjp0k9g    2013-04-01                 16        0.500000
# 4  PcvbBOCOcs6_suRDH7TSTg    2012-08-16                510        4.464706
# 5  uXjR2GhCAYhqxVr21aC4vQ    2011-10-14                 14        0.214286
# 6  N2arP_u4sMGLgOZhA6ZFoQ    2013-12-20                  9        3.000000
# 7  YHJIMK_zVH_VY6HCY6bYvg    2012-06-08                  1        0.000000
# 8  g3V76Ja0XgWS1rqx0gxL_A    2007-09-11                 86        0.197674
# 9  VTL4Dep5p7XrrOtgnXdEIQ    2010-04-25                  3        1.333333
#
#    user_funny_mean  user_useful_mean  user_star_mean  user_star_std  \
# 0        18.571429         22.071429        3.571429       0.937614
# 1         3.263889          5.222222        3.902778       0.734650
# 2         0.550000          0.400000        4.850000       0.366348
# 3         0.312500          0.687500        3.750000       0.683130
# 4         2.309804          4.705882        4.107843       0.832857
# 5         0.500000          0.571429        5.000000       0.000000
# 6         0.555556          2.444444        4.333333       0.866025
# 7         1.000000          0.000000        3.000000       0.000000
# 8         0.127907          0.430233        3.755814       1.245567
# 9         0.333333          2.000000        4.666667       0.577350
#
#    user_polarity_mean  user_polarity_std  user_subjectivity_mean  \
# 0            0.177970           0.106062                0.563582
# 1            0.220047           0.104949                0.559004
# 2            0.425986           0.213721                0.646139
# 3            0.259618           0.099733                0.562014
# 4            0.358967           0.180560                0.620263
# 5            0.279822           0.379623                0.653780
# 6            0.322131           0.098181                0.608021
# 7            0.195076           0.000000                0.531439
# 8            0.212151           0.192327                0.563515
# 9            0.291667           0.094989                0.558890
#
#    user_subjectivity_std
# 0               0.068131
# 1               0.090721
# 2               0.114380
# 3               0.081573
# 4               0.115157
# 5               0.115426
# 6               0.087161
# 7               0.000000
# 8               0.147443
# 9               0.052442

# %%
# d['U'].to_csv(parent_dir + 'user.csv')

# %%
d['U'].head(1)
# Out:
#    average_stars                                             elite  fans  \
# 0            3.8  [2014, 2016, 2013, 2011, 2012, 2015, 2010, 2017]   209
#
#                                              friends user_name  \
# 0  ['M19NwFwAXKRZzt8koF11hQ', 'QRcMZ8pJJBBZaKubHO...       Cin
#
#                   user_id yelping_since  user_review_count  user_cool_mean  \
# 0  lsSiIjAKVl-QRxKjRErBeg    2010-07-13                 14       19.714286
#
#    user_funny_mean  user_useful_mean  user_star_mean  user_star_std  \
# 0        18.571429         22.071429        3.571429       0.937614
#
#    user_polarity_mean  user_polarity_std  user_subjectivity_mean  \
# 0             0.17797           0.106062                0.563582
#
#    user_subjectivity_std
# 0               0.068131

# %%
d['RB'] = d['B'][['business_id']].merge(d['R'], on = 'business_id', how = 'left')
grouped = d['RB'].groupby('business_id').agg(['count', 'mean', 'std'])
res = pd.DataFrame(grouped.to_records())
print(list(res))
res = res[["business_id", "('review_cool', 'count')", "('review_cool', 'mean')", "('review_funny', 'mean')",\
           "('review_useful', 'mean')", "('review_stars', 'mean')", "('review_stars', 'std')",\
           "('polarity', 'mean')", "('polarity', 'std')", "('subjectivity', 'mean')", "('subjectivity', 'std')"]]

res = res.rename(columns = {"('review_cool', 'count')":"buz_review_count", "('review_cool', 'mean')":"buz_cool_mean", \
                      "('review_funny', 'mean')":"buz_funny_mean","('review_useful', 'mean')":"buz_useful_mean", \
                      "('review_stars', 'mean')":"buz_star_mean", "('review_stars', 'std')":"buz_star_std", \
                      "('polarity', 'mean')":"buz_polarity_mean", "('polarity', 'std')":"buz_polarity_std", \
                      "('subjectivity', 'mean')":"buz_subjectivity_mean", "('subjectivity', 'std')":"buz_subjectivity_std"})
res = res.fillna(0)
res.head()
# Out:
# ['business_id', "('review_cool', 'count')", "('review_cool', 'mean')", "('review_cool', 'std')", "('review_funny', 'count')", "('review_funny', 'mean')", "('review_funny', 'std')", "('review_stars', 'count')", "('review_stars', 'mean')", "('review_stars', 'std')", "('review_useful', 'count')", "('review_useful', 'mean')", "('review_useful', 'std')", "('polarity', 'count')", "('polarity', 'mean')", "('polarity', 'std')", "('subjectivity', 'count')", "('subjectivity', 'mean')", "('subjectivity', 'std')"]
#               business_id  buz_review_count  buz_cool_mean  buz_funny_mean  \
# 0  --6MefnULPED_I942VcFNA                30       0.800000        0.666667
# 1  --7zmmkVg-IMGaXbuVd0SQ                42       0.809524        0.404762
# 2  --9QQLMTbFzLJ_oT-ON3Xw                 9       0.222222        0.333333
# 3  --9e1ONYQuAa-CB_Rrw7Tw              1389       0.631389        0.471562
# 4  --DaPTJW3-tB1vP-PfdTEg                37       0.081081        0.000000
#
#    buz_useful_mean  buz_star_mean  buz_star_std  buz_polarity_mean  \
# 0         1.000000       3.233333      1.278019           0.196373
# 1         1.309524       3.904762      1.122052           0.256366
# 2         0.888889       3.000000      1.802776           0.130629
# 3         0.942405       4.087113      1.105546           0.321624
# 4         0.216216       3.648649      1.252025           0.314294
#
#    buz_polarity_std  buz_subjectivity_mean  buz_subjectivity_std
# 0          0.192862               0.514233              0.090911
# 1          0.276829               0.596447              0.123973
# 2          0.159182               0.536588              0.167924
# 3          0.193368               0.583644              0.116670
# 4          0.219135               0.576406              0.133092

# %%
print(list(d['B']))
# Out:
# ['address', 'attributes', 'business_id', 'categories', 'city', 'hours', 'is_open', 'latitude', 'longitude', 'buz_name', 'neighborhood', 'postal_code', 'buz_review_count', 'buz_stars', 'state', 'price', 'credit_card']

# %%
d['B'] = pd.read_csv(parent_dir + 'business_s.csv').drop('Unnamed: 0', 1)

d['B'] = d['B'][d['B']['review_count'] >= min_review_per_valid_buz]
d['B'] = d['B'].rename(columns = {'name':'buz_name', 'review_count':'buz_review_count_original', 'stars':'buz_stars'})
print(d['B'].shape)
print(list(d['B']))
# Out:
# (102497, 17)
# ['address', 'attributes', 'business_id', 'categories', 'city', 'hours', 'is_open', 'latitude', 'longitude', 'buz_name', 'neighborhood', 'postal_code', 'buz_review_count_original', 'buz_stars', 'state', 'price', 'credit_card']

# %%
d['B'] = d['B'].merge(res, on = 'business_id', how = 'left')
d['B'].head(10)
# Out:
#                      address  \
# 0            691 Richmond Rd
# 1        337 Danforth Avenue
# 2             4719 N 20Th St
# 3        2017 E Camelback Rd
# 4    4425 N 24th St, Ste 125
# 5             5770 Butler St
# 6         3220 Washington Rd
# 7  1425 S Higley Rd, Ste 103
# 8    11022 W Charleston Blvd
# 9    9393 N 90th St, Ste 112
#
#                                           attributes             business_id  \
# 0  {'RestaurantsPriceRange2': 2, 'BikeParking': T...  YDf95gJZaq05wvo7hTQbbQ
# 1  {'OutdoorSeating': False, 'WiFi': 'no', 'Wheel...  v2WhjAB3PIBA8J8VxG3wEg
# 2  {'OutdoorSeating': False, 'WiFi': 'no', 'Resta...  duHFBe87uNSXImQmvBh87Q
# 3  {'BusinessAcceptsCreditCards': True, 'BikePark...  uUEMrhJiL1a1pCA_I1SU7Q
# 4  {'BusinessAcceptsCreditCards': True, 'AcceptsI...  2eJEUJIP54tex7T9YOcLSw
# 5               {'BusinessAcceptsCreditCards': True}  fEylCY3UEH8YJ0Xa7lu6lA
# 6  {'WheelchairAccessible': True, 'RestaurantsPri...  kFtuYklkAIlmYw8RZAieGw
# 7  {'BusinessAcceptsCreditCards': True, 'AcceptsI...  NqiQdFa93wzUJGo29NbTPQ
# 8  {'BusinessAcceptsCreditCards': True, 'BikePark...  N9BN9ldVl1FNzcB9_eAstw
# 9  {'HairSpecializesIn': {'perms': False, 'africa...  6s3z3TlpHOIecuSyPEOp7A
#
#                                           categories              city  \
# 0                   ['Shopping', 'Shopping Centers']  Richmond Heights
# 1                           ['Food', 'Coffee & Tea']           Toronto
# 2                      ['Sandwiches', 'Restaurants']           Phoenix
# 3                      ['Shopping', 'Tobacco Shops']           Phoenix
# 4              ['Chiropractors', 'Health & Medical']           Phoenix
# 5  ['Automotive', 'Oil Change Stations', 'Car Was...        Pittsburgh
# 6  ['Jewelry Repair', 'Gold Buyers', 'Local Servi...          McMurray
# 7               ['Health & Medical', 'Optometrists']           Gilbert
# 8                         ['Bowling', 'Active Life']         Las Vegas
# 9  ['Barbers', "Men's Hair Salons", 'Hair Removal...        Scottsdale
#
#                                                hours  is_open   latitude  \
# 0  {'Sunday': '11:00-18:00', 'Wednesday': '10:00-...        1  41.541716
# 1  {'Sunday': '12:00-17:00', 'Wednesday': '10:00-...        0  43.677126
# 2                                                 {}        0  33.505928
# 3  {'Sunday': '10:00-19:00', 'Wednesday': '10:00-...        0  33.508068
# 4  {'Monday': '14:30-17:00', 'Tuesday': '14:00-19...        1  33.502848
# 5  {'Sunday': '8:00-16:30', 'Wednesday': '8:00-17...        1  40.485939
# 6  {'Wednesday': '10:00-20:00', 'Thursday': '10:0...        1  40.290498
# 7  {'Monday': '7:30-17:00', 'Tuesday': '7:30-17:0...        1  33.324539
# 8                                                 {}        1  36.159098
# 9  {'Wednesday': '10:00-18:00', 'Thursday': '10:0...        0  33.570421
#
#     longitude                     buz_name   neighborhood postal_code  \
# 0  -81.493116         Richmond Town Square            NaN       44143
# 1  -79.353285             The Tea Emporium      Riverdale     M4K 1N7
# 2 -112.038847                      Blimpie            NaN       85016
# 3 -112.037552              Baxter's Cigars            NaN       85016
# 4 -112.012696     Back-Health Chiropractic            NaN       85016
# 5  -79.943727                Auto Bathouse  Lawrenceville       15201
# 6  -80.110021          JAB Jewelry Designs            NaN       15317
# 7 -111.720449   Neighborhood Vision Center            NaN       85296
# 8 -115.337915  Red Rock Bowling UYE Part 2      Summerlin       89135
# 9 -111.886492                      Sq Cutz            NaN       85258
#
#    buz_review_count_original  buz_stars state  price credit_card  \
# 0                         17        2.0    OH    2.0         NaN
# 1                          7        4.5    ON    2.0        True
# 2                         10        4.5    AZ    1.0        True
# 3                         35        5.0    AZ    2.0        True
# 4                         19        5.0    AZ    NaN        True
# 5                         16        2.5    PA    NaN        True
# 6                          7        5.0    PA    2.0        True
# 7                          8        5.0    AZ    NaN        True
# 8                         13        4.5    NV    NaN        True
# 9                          7        4.5    AZ    2.0        True
#
#    buz_review_count  buz_cool_mean  buz_funny_mean  buz_useful_mean  \
# 0                17       0.176471        0.470588         1.235294
# 1                 7       0.714286        0.142857         0.857143
# 2                10       0.800000        0.500000         0.900000
# 3                35       0.200000        0.200000         0.514286
# 4                19       0.052632        0.000000         0.052632
# 5                16       0.437500        0.187500         1.062500
# 6                 7       0.285714        0.000000         0.285714
# 7                 8       0.125000        0.000000         0.250000
# 8                13       4.615385        4.000000         3.923077
# 9                 7       0.000000        0.285714         0.000000
#
#    buz_star_mean  buz_star_std  buz_polarity_mean  buz_polarity_std  \
# 0       2.058824      0.966345           0.170270          0.191149
# 1       4.285714      0.755929           0.218827          0.067684
# 2       4.600000      0.699206           0.282466          0.239150
# 3       5.000000      0.000000           0.392109          0.177307
# 4       4.789474      0.713283           0.270686          0.115237
# 5       2.312500      1.740450           0.009312          0.167826
# 6       5.000000      0.000000           0.395844          0.187387
# 7       5.000000      0.000000           0.344961          0.173680
# 8       4.615385      1.120897           0.242133          0.139878
# 9       4.285714      1.496026           0.230783          0.232248
#
#    buz_subjectivity_mean  buz_subjectivity_std
# 0               0.613203              0.120936
# 1               0.532261              0.061219
# 2               0.548494              0.089913
# 3               0.574468              0.099517
# 4               0.469295              0.128543
# 5               0.498867              0.143863
# 6               0.637869              0.163250
# 7               0.574378              0.178266
# 8               0.544664              0.134789
# 9               0.517781              0.149310

# %%
d['B'] = d['B'].drop(['buz_review_count_original', 'buz_stars'], axis = 1)

# %%
# d['B'].to_csv(parent_dir + 'business_s.csv')
